# %% [markdown]
# Qwen2.5-0.5b-Test-ft: https://huggingface.co/KingNish/Qwen2.5-0.5b-Test-ft

# %%
# !pip install transformers accelerate

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Model name on Hugging Face
model_name = "KingNish/Qwen2.5-0.5b-Test-ft"

# Load the model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",  # Automatically choose precision based on the device
    device_map="auto"    # Automatically map the model to the GPU if available
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/657 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]

# %%
context = """
In 2010, amidst the rapidly evolving tech landscape, Novatek Dynamics emerged as a pioneering force in enterprise software solutions.
Headquartered in Dubai, the company quickly gained international recognition for its innovative cloud infrastructure, which accelerated
digital transformation for Fortune 500 clients. The company initially faced challenges in convincing traditional enterprises to adopt
AI-driven workflows, but Hassan, the visionary CEO, led the efforts to educate clients on AI's potential to streamline their operations.
"""
question = "What challenges did Novatek Dynamics face in 2010?"

# %%
# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context}\nQuestion: {question}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: What a great question! Based on the context provided, here are some of the key challenges that Novatek Dynamics faced in 2010:
#
# 1. **Initial resistance from traditional enterprises**: Novatek Dynamics had to convince non-IT professionals and executives who were accustomed to traditional IT environments about the benefits of adopting AI-driven workflows.
# 2. **Challenges in implementing AI technologies**: The company encountered difficulties in integrating AI technologies with existing systems, especially those that were not well-suited to AI applications.
# 3. **Lack of expertise and resources**: Novatek Dynamics struggled to find the right people with the necessary skills, experience, and resources to implement AI projects successfully.
# 4. **Resistance to change**: Traditional enterprises often resisted changes in business models, processes, and cultures, making it challenging to shift to an AI-first approach.
# ...

# %%
context1 = """
In 2001, a research group led by Dr. Emily Clarkson at the University of Manchester initiated a groundbreaking project on renewable energy.
 Their focus was on harnessing tidal currents to generate sustainable electricity. By 2007, their prototypes demonstrated significant success,
  with tidal energy conversion rates exceeding initial projections. Clarkson’s contributions extended beyond research; her leadership in advocating
   for eco-friendly policies influenced regional governments to fund similar ventures. Under her vision, the SeaVolt Initiative emerged, attracting global
   interest in marine energy technologies. Although Dr. Clarkson transitioned to a consultancy role in 2012, her pioneering spirit remains integral to the project’s ongoing success.
"""

question1 = "What was the primary focus of Dr. Emily Clarkson’s research group in 2001"



# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context1}\nQuestion: {question1}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: What a fascinating question!
#
# Based on the information provided in the context, the primary focus of Dr. Emily Clarkson's research group in 2001 was:
#
# **Harnessing tidal currents to generate sustainable electricity**
#
# This is evident from several key points in the text:
#
# * The group focused on developing a prototype that demonstrated significant success in generating electricity using tidal energy.
# * They were working towards achieving a specific goal (i.e., converting tidal energy into usable electricity) within a certain timeframe.
# * The project involved testing and validating the feasibility of this method of generating electricity from tidal currents.
# * This work was part of an ongoing research initiative aimed at exploring new ways to harness the power of tidal energy.
#
# ...

# %%
context2 = """Blue Apex Technologies, established in 2016, quickly became a leading name in cybersecurity innovation. The firm specializes in developing intrusion
detection systems that identify malicious activities in real time. Their flagship product, Sentinel Shield, earned them critical acclaim for thwarting a series of
ransomware attacks in 2019. The company operates under a flat organizational structure, fostering creative problem-solving among engineers and analysts alike.
Although their Chief Technology Officer, Ahmed Khalid, is often recognized for technical breakthroughs, it was the company’s co-founder, Sarah Lin, who secured
critical seed funding and set the strategic direction during its formative years. Her financial foresight ensured Blue Apex's rapid scalability and market dominance."""


question2 = "What specific role did Sarah Lin play during the formative years of the company?"



# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context2}\nQuestion: {question2}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: During the formative years of Blue Apex Technologies, Sarah Lin played a crucial role as the founder and CEO of the company. She was responsible for shaping the company's strategic direction, overseeing the development of new products and services, and ensuring the company's continued growth.
#
# In addition to her technical expertise, Sarah was also an influential figure within the company. She was known for her visionary leadership style, which helped to inspire the team to pursue innovative ideas and drive the company towards success. As such, she was instrumental in securing critical seed funding and setting the strategic direction during its early stages.
#
# Key aspects of Sarah Lin's role during the formative years include:
#
# 1. **Visionary Leadership**: Sarah was able to articulate the company's long-term vision and goals, inspiring others to work towards achieving them.
# ...

# %%
context3 = """During the 18th century, British botanist Sir Edmund Harrington embarked on an expedition to the Pacific Islands to catalog exotic plant species.
 His observations led to the discovery of the Harringtonia floribunda, a flowering plant renowned for its medicinal properties. Years later, pharmacologists
 isolated compounds from this plant that proved effective in treating fever-related ailments. Despite his significant scientific contributions, Harrington's
  journey was fraught with challenges, including harsh weather conditions and limited resources. By the end of his career, his work laid the foundation for
   modern ethnobotany, but he remained modest about his accomplishments."""


question3 = "What challenges did Sir Edmund Harrington face during his expedition?"


# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context3}\nQuestion: {question3}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: During his expedition to the Pacific Islands in the 18th century, Sir Edmund Harrington faced several challenges that significantly impacted his research and eventual discovery of the Harringtonia floribunda. Here are some of the key challenges he encountered:
#
# 1. **Hazardous Weather Conditions**: The Pacific Islands were known for their high humidity, which could be extremely oppressive during the winter months when Harrington would have been working. The dense foggy atmosphere could also hinder visibility and make it difficult to navigate through the island jungles.
# 2. **Limited Resources**: Harrington had to rely heavily on local resources, such as wildflowers and insects, to collect specimens for his botanical study. This limited access to traditional medicine and herbal remedies made it challenging to develop new treatments for diseases.
# ...

# %%
context4 = """In 2014, Global Minds Academy revolutionized online education by introducing a flexible, modular learning framework for undergraduate studies.
The academy’s approach was initially met with skepticism, but its founder and principal architect, Maria Delgado, persisted in her mission to create an affordable
platform for students worldwide. By 2020, Global Minds had over 500,000 active learners, with customized courses designed by professors from leading universities.
While Delgado continues to oversee curriculum innovation as the academy's President, the organization’s operations are largely managed by its CEO, Dr. Kenneth Zhang,
who focuses on business expansion and partnerships."""

question4 = "What was Maria Delgado’s mission in establishing Global Minds Academy?"



# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context4}\nQuestion: {question4}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: Maria Delgado's mission in establishing Global Minds Academy was to revolutionize online education by introducing a flexible, modular learning framework that catered to diverse student needs and provided affordable access to high-quality education. Her goal was to create a platform that could support the growth of higher education globally, making it accessible to students from various backgrounds and institutions.
#
# Delgado recognized the need for a more inclusive and responsive educational system, which would not only meet the demands of traditional university-level programs but also ensure that all students, regardless of their background or financial circumstances, had equal opportunities to succeed. She believed that education should be a fundamental right, and she aimed to make it a reality through the creation of a flexible, adaptive learning environment.
#
# By 2020, Global Minds Academy had achieved significant milestones in its mission:
#
# ...

# %%
context5 =  """At the peak of the industrial revolution, Lonsdale & Sons emerged as a cornerstone of British textile manufacturing. The company thrived
under the leadership of Thomas Lonsdale, who introduced automated looms that doubled production efficiency. By the 1880s, their mills employed thousands
 of workers, with fabrics exported across Europe and the Americas. While Thomas was widely regarded as the face of the company, it was his wife, Eleanor
  Lonsdale, who managed finances and brokered deals with major trading partners. Her strategic negotiations ensured the company’s survival during economic
  downturns, though her contributions were rarely acknowledged publicly. """

question5 = "Who was responsible for negotiating deals with trading partners for Lonsdale & Sons?"


# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context5}\nQuestion: {question5}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: Based on the context provided, the person responsible for negotiating deals with trading partners at Lonsdale & Sons is Eleanor Lonsdale. She was Thomas Lonsdale's wife and played an important role in managing financial affairs and ensuring the company's survival during economic downturns.

# %%
context6 =  """In the early 21st century, urban planner Hassan Qureshi introduced a radical design concept for sustainable cities. His Vertical Eco-Towers
 combined residential, commercial, and agricultural spaces within high-rise buildings, significantly reducing urban sprawl. Piloted in Singapore in 2025,
  these towers achieved a 40% decrease in energy consumption through integrated solar and wind systems. Qureshi’s idea was not without critics; many doubted
   the economic feasibility of such projects. However, by 2030, international adoption had proven the concept’s viability, cementing Qureshi’s reputation as a visionary."""

question6 = "What problem did Hassan Qureshi aim to solve with his Vertical Eco-Towers?"


# Prepare the prompt
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": f"Context: {context6}\nQuestion: {question6}"}
]

# Apply the chat template
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# Tokenize the input
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# Generate a response
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512  # Limit response length
)

# Decode the output
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]
response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print("Response:", response)
# Out:
# Response: Hassan Qureshi aimed to solve two major problems with his Vertical Eco-Towers:
#
# **Problem 1: Urban Sprawl**
#
# Urban planners and policymakers were concerned about the rapid growth of cities, leading to the accumulation of waste, pollution, and congestion in urban areas. As cities expanded, they became overcrowded, inefficient, and unsustainable.
#
# Qureshi's Vertical Eco-Towers addressed this issue by designing tall, vertical buildings that could integrate various functions within their structure. These towers could accommodate both residential and commercial spaces, while also providing ample open space for agriculture. By doing so, Qureshi's towers reduced the amount of land required for urban development, thereby minimizing the impact on natural habitats and ecosystems.
#
# **Problem 2: Energy Consumption**
#
# ...
