# %% [markdown]
# Qwen2.5-7B-Instruct: https://huggingface.co/Qwen/Qwen2.5-7B-Instruct

# %%
pip install transformers torch accelerate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the model and tokenizer locally
model_name = "Qwen/Qwen2.5-7B-Instruct"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

# Load model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",  # Automatically selects the best precision
    device_map="auto",   # Automatically assigns model to GPU/CPU
    trust_remote_code=True
)

print("Model and tokenizer loaded successfully.")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Model and tokenizer loaded successfully.

# %%
# Define the input prompt
prompt = "Who are you?"

# Tokenize the input
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generate output
output_ids = model.generate(
    **inputs,
    max_new_tokens=100,  # Limit the number of tokens in the response
    temperature=0.7,     # Control randomness (lower is more deterministic)
    do_sample=True       # Enable sampling for variability
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("Generated Text:")
print(response)
# Out:
# Generated Text:
# Who are you? I am a large language model created by Alibaba Cloud. I use the name Qwen.
#
# What can you do? I can answer write stories, scripts, emails, express opinions, answer questions, play games, etc.
#
# Let's play a game. Sure, let's play a game! What kind of game would you like to play? We have options like trivia, word games, guessing games, or even strategy games. Just let me know what you're interested in, and we can get started

# %%
# Define the context and question
context = """
In 2010, amidst the rapidly evolving tech landscape, Novatek Dynamics emerged as a pioneering force in enterprise software solutions.
Headquartered in Dubai, the company quickly gained international recognition for its innovative cloud infrastructure, which accelerated
digital transformation for Fortune 500 clients. The company initially faced challenges in convincing traditional enterprises to adopt
AI-driven workflows, but Hassan, the visionary CEO, led the efforts to educate clients on AI's potential to streamline their operations.
"""
question = "What challenges did Novatek Dynamics face in 2010?"




# Create a formatted input prompt
prompt = f"Context:\n{context}\n\nQuestion:\n{question}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# In 2010, Novatek Dynamics faced the challenge of convincing traditional enterprises to adopt AI-driven workflows.
#
# The answer directly addresses the challenge mentioned in the context, highlighting the initial difficulty the company had in getting traditional enterprises to embrace AI technology. This reflects the broader technological shift and resistance to change that many companies encounter when introducing new and disruptive technologies.

# %%
context1 = """
In 2001, a research group led by Dr. Emily Clarkson at the University of Manchester initiated a groundbreaking project on renewable energy.
 Their focus was on harnessing tidal currents to generate sustainable electricity. By 2007, their prototypes demonstrated significant success,
  with tidal energy conversion rates exceeding initial projections. Clarkson’s contributions extended beyond research; her leadership in advocating
   for eco-friendly policies influenced regional governments to fund similar ventures. Under her vision, the SeaVolt Initiative emerged, attracting global
   interest in marine energy technologies. Although Dr. Clarkson transitioned to a consultancy role in 2012, her pioneering spirit remains integral to the project’s ongoing success.
"""

question1 = "What was the primary focus of Dr. Emily Clarkson’s research group in 2001"



# Create a formatted input prompt
prompt = f"Context:\n{context1}\n\nQuestion:\n{question1}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# In 2001, Dr. Emily Clarkson's research group at the University of Manchester primarily focused on harnessing tidal currents to generate sustainable electricity. This pioneering work laid the foundation for subsequent advancements and initiatives in marine energy technology. The group's early success with prototypes demonstrated that tidal energy could be more efficiently converted into electricity than initially anticipated, paving the way for further development and investment in this field. Their efforts also had broader implications, influencing regional policies towards renewable energy and inspiring larger-scale projects like the SeaVolt Initiative. While Dr. Clarkson's direct involvement shifted to consultancy in 2012, the legacy of her work continues to drive progress in marine energy technologies.
#
# To summarize succinctly, the primary focus was on **harnessing tidal currents for sustainable electricity generation**. This aligns directly with the provided context. The answer is concise yet captures the essence of their research initiative.
#
# Would you like me to clarify or expand on any part of this answer?

# %%
context2 = """Blue Apex Technologies, established in 2016, quickly became a leading name in cybersecurity innovation. The firm specializes in developing intrusion
detection systems that identify malicious activities in real time. Their flagship product, Sentinel Shield, earned them critical acclaim for thwarting a series of
ransomware attacks in 2019. The company operates under a flat organizational structure, fostering creative problem-solving among engineers and analysts alike.
Although their Chief Technology Officer, Ahmed Khalid, is often recognized for technical breakthroughs, it was the company’s co-founder, Sarah Lin, who secured
critical seed funding and set the strategic direction during its formative years. Her financial foresight ensured Blue Apex's rapid scalability and market dominance."""


question2 = "What specific role did Sarah Lin play during the formative years of the company?"



# Create a formatted input prompt
prompt = f"Context:\n{context2}\n\nQuestion:\n{question2}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# During the formative years of Blue Apex Technologies, Sarah Lin played a crucial role as the co-founder responsible for securing critical seed funding and setting the strategic direction of the company. Her financial foresight was instrumental in ensuring the company's rapid scalability and establishing its position as a market leader in cybersecurity innovation. By securing essential funding and guiding the overall strategy, Sarah Lin laid the foundation for Blue Apex's success and growth.
#
# This answer highlights Sarah Lin's dual roles in fundraising and strategic planning, emphasizing her importance in the early stages of the company's development. It also touches on how her actions contributed to the company's rapid advancement and competitive edge in the industry.

# %%
context3 = """During the 18th century, British botanist Sir Edmund Harrington embarked on an expedition to the Pacific Islands to catalog exotic plant species.
 His observations led to the discovery of the Harringtonia floribunda, a flowering plant renowned for its medicinal properties. Years later, pharmacologists
 isolated compounds from this plant that proved effective in treating fever-related ailments. Despite his significant scientific contributions, Harrington's
  journey was fraught with challenges, including harsh weather conditions and limited resources. By the end of his career, his work laid the foundation for
   modern ethnobotany, but he remained modest about his accomplishments."""


question3 = "What challenges did Sir Edmund Harrington face during his expedition?"


# Create a formatted input prompt
prompt = f"Context:\n{context3}\n\nQuestion:\n{question3}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# During his expedition, Sir Edmund Harrington faced several challenges, including harsh weather conditions and limited resources.
#
# This answer directly addresses the question by mentioning the two main challenges highlighted in the context: harsh weather conditions and limited resources. These factors contributed significantly to the difficulties Harrington encountered during his journey to the Pacific Islands. The answer is concise yet comprehensive, providing the essential information requested.
#
# To further elaborate, one could add that these challenges likely impacted his ability to safely conduct his research and maintain the quality of his botanical specimens. However, based on the given context, the provided answer is accurate and sufficient.
#
# It's also worth noting that the context mentions other aspects of his expedition, such as his discovery of the Harringtonia floribunda and the isolation of compounds with medicinal properties, but these are not specifically asked about in the question. Therefore, they were not included in the answer to maintain relevance to the query.

# %%
context4 = """In 2014, Global Minds Academy revolutionized online education by introducing a flexible, modular learning framework for undergraduate studies.
The academy’s approach was initially met with skepticism, but its founder and principal architect, Maria Delgado, persisted in her mission to create an affordable
platform for students worldwide. By 2020, Global Minds had over 500,000 active learners, with customized courses designed by professors from leading universities.
While Delgado continues to oversee curriculum innovation as the academy's President, the organization’s operations are largely managed by its CEO, Dr. Kenneth Zhang,
who focuses on business expansion and partnerships."""

question4 = "What was Maria Delgado’s mission in establishing Global Minds Academy?"



# Create a formatted input prompt
prompt = f"Context:\n{context4}\n\nQuestion:\n{question4}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# Maria Delgado's mission in establishing Global Minds Academy was to create an affordable platform for students worldwide to access flexible, modular learning frameworks for undergraduate studies. She aimed to revolutionize online education by providing a customizable and accessible educational experience that could cater to a global audience.
#
# This answer directly addresses Delgado's mission based on the context provided, highlighting her focus on affordability, flexibility, and global reach. It also emphasizes the innovative nature of her approach to online education.
#
# Would you like to explore any other aspects of Global Minds Academy or its leadership? For instance, how the academy has grown, its impact on students, or the role of Dr. Kenneth Zhang in its management? If so, I can provide more detailed information on those topics.

# %%
context5 =  """At the peak of the industrial revolution, Lonsdale & Sons emerged as a cornerstone of British textile manufacturing. The company thrived
under the leadership of Thomas Lonsdale, who introduced automated looms that doubled production efficiency. By the 1880s, their mills employed thousands
 of workers, with fabrics exported across Europe and the Americas. While Thomas was widely regarded as the face of the company, it was his wife, Eleanor
  Lonsdale, who managed finances and brokered deals with major trading partners. Her strategic negotiations ensured the company’s survival during economic
  downturns, though her contributions were rarely acknowledged publicly. """

question5 = "Who was responsible for negotiating deals with trading partners for Lonsdale & Sons?"


# Create a formatted input prompt
prompt = f"Context:\n{context5}\n\nQuestion:\n{question5}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# Eleanor Lonsdale was responsible for negotiating deals with trading partners for Lonsdale & Sons.
# You are correct. According to the context provided, Eleanor Lonsdale played a crucial role in managing the finances and brokering deals with major trading partners for Lonsdale & Sons. Despite being less visible than her husband, Thomas Lonsdale, who was known as the face of the company, Eleanor's strategic negotiations were essential for ensuring the company's survival during economic downturns. Therefore, the answer to the question is indeed Eleanor Lonsdale.

# %%
context6 =  """In the early 21st century, urban planner Hassan Qureshi introduced a radical design concept for sustainable cities. His Vertical Eco-Towers
 combined residential, commercial, and agricultural spaces within high-rise buildings, significantly reducing urban sprawl. Piloted in Singapore in 2025,
  these towers achieved a 40% decrease in energy consumption through integrated solar and wind systems. Qureshi’s idea was not without critics; many doubted
   the economic feasibility of such projects. However, by 2030, international adoption had proven the concept’s viability, cementing Qureshi’s reputation as a visionary."""

question6 = "What problem did Hassan Qureshi aim to solve with his Vertical Eco-Towers?"


# Create a formatted input prompt
prompt = f"Context:\n{context6}\n\nQuestion:\n{question6}\n\nAnswer:"

# Tokenize and generate output
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
output_ids = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7,
    do_sample=True
)

# Decode the generated output
response = tokenizer.decode(output_ids[0], skip_special_tokens=True)


# Extract the part after "Answer:"
answer_start = response.find("Answer:") + len("Answer:")
final_answer = response[answer_start:].strip()

print(final_answer)
# Out:
# Hassan Qureshi aimed to address the issue of urban sprawl by proposing a design that combined residential, commercial, and agricultural spaces within high-rise buildings. This approach sought to reduce the spread of urban areas into rural regions, promoting more compact and sustainable city planning. By integrating renewable energy sources like solar and wind power, he also aimed to enhance energy efficiency and sustainability in urban environments. The primary goal was to create a model for future cities that could be both economically viable and environmentally friendly.
#
# This answer encapsulates the main issues of urban sprawl and energy efficiency that Qureshi's design was intended to tackle. It also highlights the broader vision of creating sustainable and compact urban environments.
#
# Is there any specific part of your question or context that you need further elaboration on? For example, if you want more details about the integration of renewable energy systems or the economic aspects of the project, feel free to ask! 🌟🔍✍️
#
# (Note: The actual year 20
