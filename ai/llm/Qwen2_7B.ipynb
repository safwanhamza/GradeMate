# %% [markdown]
# Qwen2 -7B: https://huggingface.co/Qwen/Qwen2-7B

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# Load the tokenizer and model locally
model_name = "Qwen/Qwen2-7B"

# Download and load the model to your local environment
tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir="./models", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    cache_dir="./models",
    device_map="auto",
    torch_dtype=torch.bfloat16,
    trust_remote_code=True
)

# Initialize the pipeline
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0)

# Define context and question
context = """
In 2010, amidst the rapidly evolving tech landscape, Novatek Dynamics emerged as a pioneering force in enterprise software solutions.
Headquartered in Dubai, the company quickly gained international recognition for its innovative cloud infrastructure, which accelerated
digital transformation for Fortune 500 clients. The company initially faced challenges in convincing traditional enterprises to adopt
AI-driven workflows, but Hassan, the visionary CEO, led the efforts to educate clients on AI's potential to streamline their operations.

By 2015, Novatek expanded operations across Europe and Southeast Asia. In Europe, financial institutions adopted Novatek’s solutions
to unify their fragmented customer data, improving customer service efficiency by 30%. In Southeast Asia, manufacturing industries
leveraged Novatek's analytics tools to optimize supply chain management, reducing costs by 25%.

Hassan conceptualized Novatek Dynamics as a platform to unify corporate workflows, addressing inefficiencies caused by disconnected systems.
By combining AI-driven analytics with enterprise systems, the company provided businesses with actionable insights to improve decision-making
and operational efficiency. Under Hassan’s leadership, Novatek Dynamics received multiple accolades, including the prestigious Global
Innovation Award in 2021. This award recognized Novatek's pioneering integration of AI with cloud solutions, which set new standards
for enterprise software performance. Despite challenges posed by global competitors, Hassan's strategy of continuous innovation and
client-centric solutions enabled Novatek to maintain its edge.

Today, Novatek Dynamics continues to redefine organizational efficiency by bridging gaps in technology adoption. By offering customized
solutions for various industries, Novatek empowers companies to embrace digital transformation seamlessly. Hassan remains at the forefront
of this mission, shaping the company's strategy and envisioning future advancements in enterprise technology.
"""

question = "What challenges might Hassan have faced when conceptualizing the platform, and how could his leadership have overcome them?"

# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context}\n\nQuestion: {question}\n\nAnswer:"""

# Generate the answer
output = pipe(prompt, max_length=300, do_sample=True, temperature=0.7)

# Print the answer
print(output[0]["generated_text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/664 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# ...

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# %%
# Model name
model_name = "Qwen/Qwen2-7B"

# Load the tokenizer and model into memory
tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir="./models", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    cache_dir="./models",
    device_map="auto",  # Auto-manage GPU/CPU usage
    torch_dtype=torch.bfloat16,  # Efficient memory use
    trust_remote_code=True
)

print("Model and tokenizer loaded successfully.")

# %%
# Initialize pipeline without device argument (device_map already handles it)
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)

print("Pipeline initialized.")
# Out:
# Pipeline initialized.

# %%
# Context and question
context = """
In 2010, amidst the rapidly evolving tech landscape, Novatek Dynamics emerged as a pioneering force in enterprise software solutions.
Headquartered in Dubai, the company quickly gained international recognition for its innovative cloud infrastructure, which accelerated
digital transformation for Fortune 500 clients. The company initially faced challenges in convincing traditional enterprises to adopt
AI-driven workflows, but Hassan, the visionary CEO, led the efforts to educate clients on AI's potential to streamline their operations.

By 2015, Novatek expanded operations across Europe and Southeast Asia. In Europe, financial institutions adopted Novatek’s solutions
to unify their fragmented customer data, improving customer service efficiency by 30%. In Southeast Asia, manufacturing industries
leveraged Novatek's analytics tools to optimize supply chain management, reducing costs by 25%.

Hassan conceptualized Novatek Dynamics as a platform to unify corporate workflows, addressing inefficiencies caused by disconnected systems.
By combining AI-driven analytics with enterprise systems, the company provided businesses with actionable insights to improve decision-making
and operational efficiency. Under Hassan’s leadership, Novatek Dynamics received multiple accolades, including the prestigious Global
Innovation Award in 2021. This award recognized Novatek's pioneering integration of AI with cloud solutions, which set new standards
for enterprise software performance. Despite challenges posed by global competitors, Hassan's strategy of continuous innovation and
client-centric solutions enabled Novatek to maintain its edge.

Today, Novatek Dynamics continues to redefine organizational efficiency by bridging gaps in technology adoption. By offering customized
solutions for various industries, Novatek empowers companies to embrace digital transformation seamlessly. Hassan remains at the forefront
of this mission, shaping the company's strategy and envisioning future advancements in enterprise technology.
"""

question = "What challenges might Hassan have faced when conceptualizing the platform, and how could his leadership have overcome them?"

# %%
context1 = """
In 2001, a research group led by Dr. Emily Clarkson at the University of Manchester initiated a groundbreaking project on renewable energy.
 Their focus was on harnessing tidal currents to generate sustainable electricity. By 2007, their prototypes demonstrated significant success,
  with tidal energy conversion rates exceeding initial projections. Clarkson’s contributions extended beyond research; her leadership in advocating
   for eco-friendly policies influenced regional governments to fund similar ventures. Under her vision, the SeaVolt Initiative emerged, attracting global
   interest in marine energy technologies. Although Dr. Clarkson transitioned to a consultancy role in 2012, her pioneering spirit remains integral to the project’s ongoing success.
"""

question1 = "What was the primary focus of Dr. Emily Clarkson’s research group in 2001"

# %%
context2 = """Blue Apex Technologies, established in 2016, quickly became a leading name in cybersecurity innovation. The firm specializes in developing intrusion
detection systems that identify malicious activities in real time. Their flagship product, Sentinel Shield, earned them critical acclaim for thwarting a series of
ransomware attacks in 2019. The company operates under a flat organizational structure, fostering creative problem-solving among engineers and analysts alike.
Although their Chief Technology Officer, Ahmed Khalid, is often recognized for technical breakthroughs, it was the company’s co-founder, Sarah Lin, who secured
critical seed funding and set the strategic direction during its formative years. Her financial foresight ensured Blue Apex's rapid scalability and market dominance."""


question2 = "What specific role did Sarah Lin play during the formative years of the company?"

# %%
context3 = """During the 18th century, British botanist Sir Edmund Harrington embarked on an expedition to the Pacific Islands to catalog exotic plant species.
 His observations led to the discovery of the Harringtonia floribunda, a flowering plant renowned for its medicinal properties. Years later, pharmacologists
 isolated compounds from this plant that proved effective in treating fever-related ailments. Despite his significant scientific contributions, Harrington's
  journey was fraught with challenges, including harsh weather conditions and limited resources. By the end of his career, his work laid the foundation for
   modern ethnobotany, but he remained modest about his accomplishments."""


question3 = "What challenges did Sir Edmund Harrington face during his expedition?"

# %%
context4 = """In 2014, Global Minds Academy revolutionized online education by introducing a flexible, modular learning framework for undergraduate studies.
The academy’s approach was initially met with skepticism, but its founder and principal architect, Maria Delgado, persisted in her mission to create an affordable
platform for students worldwide. By 2020, Global Minds had over 500,000 active learners, with customized courses designed by professors from leading universities.
While Delgado continues to oversee curriculum innovation as the academy's President, the organization’s operations are largely managed by its CEO, Dr. Kenneth Zhang,
who focuses on business expansion and partnerships."""

question4 = "What was Maria Delgado’s mission in establishing Global Minds Academy?"

# %%
context5 =  """At the peak of the industrial revolution, Lonsdale & Sons emerged as a cornerstone of British textile manufacturing. The company thrived
under the leadership of Thomas Lonsdale, who introduced automated looms that doubled production efficiency. By the 1880s, their mills employed thousands
 of workers, with fabrics exported across Europe and the Americas. While Thomas was widely regarded as the face of the company, it was his wife, Eleanor
  Lonsdale, who managed finances and brokered deals with major trading partners. Her strategic negotiations ensured the company’s survival during economic
  downturns, though her contributions were rarely acknowledged publicly. """

question5 = "Who was responsible for negotiating deals with trading partners for Lonsdale & Sons?"

# %%
context6 =  """In the early 21st century, urban planner Hassan Qureshi introduced a radical design concept for sustainable cities. His Vertical Eco-Towers
 combined residential, commercial, and agricultural spaces within high-rise buildings, significantly reducing urban sprawl. Piloted in Singapore in 2025,
  these towers achieved a 40% decrease in energy consumption through integrated solar and wind systems. Qureshi’s idea was not without critics; many doubted
   the economic feasibility of such projects. However, by 2030, international adoption had proven the concept’s viability, cementing Qureshi’s reputation as a visionary."""

question6 = "What problem did Hassan Qureshi aim to solve with his Vertical Eco-Towers?"

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context}\n\nQuestion: {question}\n\nAnswer:"""

# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before "Answer:" to clean up the output
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Format the final output
formatted_answer = "\n".join([
    "### Generated Answer:\n",
    f"**Summary:**\n{answer.split('.', 1)[0].strip()}.",  # First sentence as a summary
    "\n**Detailed Explanation:**",
    "\n".join(["- " + line.strip() for line in answer.split('. ')[1:] if line])  # Bullet points for detail
])

# Print the formatted output
print(formatted_answer)
# Out:
# ### Generated Answer:
#
# **Summary:**
# Hassan, the visionary CEO of Novatek Dynamics, faced several challenges when conceptualizing the platform aimed at unifying corporate workflows and addressing disconnected systems.
#
# **Detailed Explanation:**
# - Some of the challenges he might have faced include:
#
# 1
# - Resistance to change: Traditional enterprises might have been hesitant to adopt new technologies and workflows, fearing disruption to their established processes and potential loss of control
# - Hassan could have overcome this by educating clients on the potential benefits of AI-driven solutions, such as increased efficiency, cost savings, and improved decision-making
# - By demonstrating successful case studies and providing tailored solutions for specific industries, Hassan could have helped clients see the value in adopting the platform.
#
# 2
# ...

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context1}\n\nQuestion: {question1}\n\nAnswer:"""


# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before the word "Answer:" to keep only the answer
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Print the extracted answer
print("Generated Answer:")
print(answer)
# Out:
# Generated Answer:
# The primary focus of Dr. Emily Clarkson's research group in 2001 was on harnessing tidal currents to generate sustainable electricity. With their groundbreaking project, they aimed to tap into the untapped potential of marine energy, specifically tidal energy. By 2007, their prototypes demonstrated significant success, with tidal energy conversion rates exceeding initial projections. This research not only held tremendous potential for renewable energy but also had a significant impact on regional governments and global interest in marine energy technologies. Dr. Clarkson's contributions extended beyond research, as she also led the advocacy for eco-friendly policies, which attracted funding for similar ventures. Despite her transition to a consultancy role in 2012, her pioneering spirit remains an integral part of the project's ongoing success.

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context2}\n\nQuestion: {question2}\n\nAnswer:"""


# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before the word "Answer:" to keep only the answer
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Print the extracted answer
print("Generated Answer:")
print(answer)
# Out:
# Generated Answer:
# During the formative years of Blue Apex Technologies, Sarah Lin played a critical role in securing seed funding and setting the company's strategic direction. Her financial foresight was instrumental in ensuring the company's rapid scalability and market dominance.

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context3}\n\nQuestion: {question3}\n\nAnswer:"""


# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before the word "Answer:" to keep only the answer
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Print the extracted answer
print("Generated Answer:")
print(answer)
# Out:
# Generated Answer:
# Sir Edmund Harrington faced several challenges during his expedition to the Pacific Islands. The harsh weather conditions, such as unpredictable storms and extreme heat, posed a significant threat to his well-being and the preservation of the specimens he was collecting. Additionally, limited resources, such as food, water, and supplies, made it difficult for him to sustain himself and maintain his research efforts. Despite these challenges, Harrington persevered, collecting valuable data and observations that would later contribute greatly to the field of botany and medicine.

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context4}\n\nQuestion: {question4}\n\nAnswer:"""


# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before the word "Answer:" to keep only the answer
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Print the extracted answer
print("Generated Answer:")
print(answer)
# Out:
# Generated Answer:
# Maria Delgado's mission in establishing Global Minds Academy was to create an affordable platform for students worldwide to access customized courses designed by professors from leading universities. By revolutionizing online education in 2014 with a flexible, modular learning framework for undergraduate studies, she aimed to democratize higher education and make it more accessible to a broader audience, addressing the skepticism that her innovative approach initially faced.

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context5}\n\nQuestion: {question5}\n\nAnswer:"""


# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before the word "Answer:" to keep only the answer
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Print the extracted answer
print("Generated Answer:")
print(answer)
# Out:
# Generated Answer:
# Eleanor Lonsdale was responsible for negotiating deals with trading partners for Lonsdale & Sons.

# %%
# Format the input prompt
prompt = f"""Answer the question based on the following context:\n\nContext:\n{context6}\n\nQuestion: {question6}\n\nAnswer:"""


# Generate the output
output = pipe(prompt, max_new_tokens=300, do_sample=True, temperature=0.7, truncation=True)

# Extract and clean the generated text
generated_text = output[0]["generated_text"]

# Remove everything before the word "Answer:" to keep only the answer
if "Answer:" in generated_text:
    answer = generated_text.split("Answer:", 1)[1].strip()
else:
    answer = generated_text  # Fallback if "Answer:" isn't in the output

# Print the extracted answer
print("Generated Answer:")
print(answer)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Generated Answer:
# Hassan Qureshi aimed to solve the problem of urban sprawl with his Vertical Eco-Towers. These towers combined residential, commercial, and agricultural spaces within high-rise buildings, which significantly reduced the need for extensive urban expansion. By doing so, Qureshi's design concept contributed to the sustainability of cities, addressing one of the key challenges faced by urban centers in the 21st century.
